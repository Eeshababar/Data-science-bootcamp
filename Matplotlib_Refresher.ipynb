# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Note: Unlike the plural of axis, axes in Matplotlib is actually the whole rectangular box containing the axis lines, ticks and labels.

# %%
x = pd.read_csv("/content/Standard_Metropolitan_Areas_Data-data.csv")

# %%
x.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
df1.graduates.nonnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-22083ea3d5ff> in <module>()
# ----> 1 df1.graduates.nonnull()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'nonnull'

# %%
df1 = x[x['region'] == 3]

# %%
df1.describe()
# Out:
#          land_area  percent_city  percent_senior   physicians  hospital_beds  \
# count    36.000000     36.000000       36.000000    36.000000      36.000000
# mean   2485.972222     46.172222        9.283333  1313.722222    4962.777778
# std    1653.813800     19.101019        3.458199  1459.654903    3879.692625
# min     654.000000     14.500000        3.900000   140.000000     481.000000
# 25%    1517.000000     31.350000        7.600000   509.750000    2483.500000
# 50%    2018.000000     47.000000        8.850000   767.000000    3876.000000
# 75%    2911.000000     59.725000        9.975000  1583.500000    5811.750000
# max    8360.000000     90.700000       21.800000  7340.000000   16941.000000
#
#        graduates   work_force        income  region  crime_rate
# count  36.000000    36.000000     36.000000    36.0   36.000000
# mean   51.002778   343.797222   4806.861111     3.0   58.265556
# std     7.328164   354.312228   5452.647656     0.0   10.155822
# ...

# %%
df1.shape
# Out:
# (36, 10)

# %%
df1.dropna()
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 12       4326          23.6             7.3        3064           9976
# 16       2045          37.2            21.4        1949           8863
# 22       1967          51.1             8.8        2520           8467
# 26       1392          37.2             9.8        1579           6087
# 27       3358          35.1            11.3        1649           5512
# 30       3214          47.7             9.4        1285           3459
# 31       3491          48.5             9.7        1496           5620
# 32       4080          59.6             9.9        1597           7496
# 34       3199          80.6             8.7         983           4749
# ...

# %%
x.region.unique()
# Out:
# array([1, 2, 4, 3])

# %%
x.mean()
# Out:
# land_area         2615.727273
# percent_city        42.518182
# percent_senior       9.781818
# physicians        1828.333333
# hospital_beds     6345.868687
# graduates           54.463636
# work_force         449.366667
# income            6762.505051
# region               2.494949
# crime_rate          55.643030
# dtype: float64

# %%
df1.describe()
# Out:
#          land_area  percent_city  percent_senior   physicians  hospital_beds  \
# count    36.000000     36.000000       36.000000    36.000000      36.000000
# mean   2485.972222     46.172222        9.283333  1313.722222    4962.777778
# std    1653.813800     19.101019        3.458199  1459.654903    3879.692625
# min     654.000000     14.500000        3.900000   140.000000     481.000000
# 25%    1517.000000     31.350000        7.600000   509.750000    2483.500000
# 50%    2018.000000     47.000000        8.850000   767.000000    3876.000000
# 75%    2911.000000     59.725000        9.975000  1583.500000    5811.750000
# max    8360.000000     90.700000       21.800000  7340.000000   16941.000000
#
#        graduates   work_force        income  region  crime_rate
# count  36.000000    36.000000     36.000000    36.0   36.000000
# mean   51.002778   343.797222   4806.861111     3.0   58.265556
# std     7.328164   354.312228   5452.647656     0.0   10.155822
# ...

# %%
x.sort_values(by = 'crime_rate', ascending = False)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 20       9155          53.8            11.1        2280           6450
# 74       1412          39.2            11.3         436           1837
# 53       5966          39.5             9.6         737           1907
# 4        2480          31.5            10.5        8502          16751
# 67       8152          22.3             9.1         405           1254
# ..        ...           ...             ...         ...            ...
# 8        3049          19.5            12.1        4005          21149
# 72       2658          39.0            12.2         365           5430
# 76        862          26.3            13.4         423           1929
# 38       1951          28.4            14.5         696           4843
# 70        946          16.4            11.1         366           1455
#
#     graduates  work_force  income  region  crime_rate
# 20       60.1       575.2    7766       4       85.62
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
x.shape
# Out:
# (99, 10)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
x.head(10)
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
# 5       2815          23.1             6.7        7340          16941
# 6       8360          46.3             8.2        4047          14347
# 7       6794          60.1             6.3        4562          14333
# 8       3049          19.5            12.1        4005          21149
# 9       4647          31.5             9.2        3916          12815
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# ...

# %%
x.tail()
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 94       50.4       127.2    1452       4       70.66
# 95       30.3        80.6     769       3       36.36
# 96       70.7        93.2    1337       3       60.16
# 97       58.0        97.0    1589       1       36.33
# 98       55.1        66.9    1148       3       68.76

# %%
(x[x.region==2]).count()
# Out:
# land_area         99
# percent_city      99
# percent_senior    99
# physicians        99
# hospital_beds     99
# graduates         99
# work_force        99
# income            99
# region            99
# crime_rate        99
# dtype: int64

# %%
x.describe
# Out:
# <bound method NDFrame.describe of     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# ...

# %%
x.info
# Out:
# <bound method DataFrame.info of     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# ...

# %%
x.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
print(x)
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
x[["region", "land_area"]].head(15)
# Out:
#     region  land_area
# 0        1       1384
# 1        2       3719
# 2        1       3553
# 3        2       3916
# 4        4       2480
# 5        3       2815
# 6        3       8360
# 7        3       6794
# 8        1       3049
# 9        2       4647
# 10       1       1008
# 11       2       1519
# 12       3       4326
# 13       4        782
# 14       4       4226

# %%
x.corr()
# Out:
#                 land_area  percent_city  percent_senior  physicians  \
# land_area        1.000000     -0.077320        0.092226    0.085054
# percent_city    -0.077320      1.000000       -0.250995    0.067391
# percent_senior   0.092226     -0.250995        1.000000    0.056454
# physicians       0.085054      0.067391        0.056454    1.000000
# hospital_beds    0.081034      0.052898        0.083775    0.974241
# graduates        0.088728      0.076720       -0.155695    0.049500
# work_force       0.135792      0.016011        0.035240    0.965597
# income           0.111404      0.019235        0.046073    0.976209
# region           0.292392      0.235880       -0.242811   -0.140961
# crime_rate       0.293907      0.159596       -0.177992    0.187763
#
#                 hospital_beds  graduates  work_force    income    region  \
# land_area            0.081034   0.088728    0.135792  0.111404  0.292392
# ...

# %%
x.head(10)
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
# 5       2815          23.1             6.7        7340          16941
# 6       8360          46.3             8.2        4047          14347
# 7       6794          60.1             6.3        4562          14333
# 8       3049          19.5            12.1        4005          21149
# 9       4647          31.5             9.2        3916          12815
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# ...

# %%
plt.scatter(x.crime_rate, x.percent_senior)
plt.show()

# %%
plt.plot(x.work_force, x.income)
plt.show()

# %%
plt.plot(x.land_area, x.crime_rate)
plt.show()

# %%
plt.plot([1,2,3,4])
plt.show()

# %% [markdown]
# You may be wondering why the x-axis ranges from 0-3 and the y-axis from 1-4.
# If you provide a list of n elements to the .plot() function, matplotlib will assume it is a sequence of y values, and automatically generates the x values for you as a range of n elements starting from 0.
# Since python ranges start with 0, the default list x has the same length as y . Hence the x data will be [0,1,2,3]. (Length same as y(4) but starts from 0 instead).

# %%
plt.hist(x.percent_senior)
plt.show()

# %%
plt.bar(x.region, x.crime_rate)
plt.show()

# %%
plt.barh(x.region, x.crime_rate)
plt.show()

# %%
Firm = ["FirmA", "FirmB", "FirmC", "FirmD", "FirmE"]
share = [40,50,60,70,80]
plt.pie(share, labels = Firm, autopct = '%1.1f%%')
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r")
plt.show()
plt.plot(x.physicians, x.income, color = "g")
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r")
plt.plot(x.physicians, x.income, color = "g") #Avoid plt.show made it one graph
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r")
plt.title("Plot of workforce against income")
plt.xlabel("work_force")
plt.ylabel("income")
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force")
plt.plot(x.physicians, x.income, color = "g", label = "physicians")
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "red", label = "work_force")
plt.show()
plt.plot(x.work_force, x.income, color = "b", label = "work_force")
plt.show()
plt.plot(x.work_force, x.income, color = "0.75", label = "work_force")
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dashed")
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = "--" )
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "solid")
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = "-" )
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dashdot")
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = "-." )
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dotted")
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = ":" )
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dotted", marker = '^')
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = ":" , marker = '^')
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dotted", marker = 'o')
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = ":" , marker = 'o')
plt.legend() #It will only work with plt.legend
plt.show()

# %%
plt.plot(x.work_force, x.income, '--ro')
plt.plot(x.physicians, x.income, '--go')
plt.show()

# %%
plt.plot(x.work_force, x.income, 'ro')
plt.plot(x.physicians, x.income, 'go')
plt.show()

# %%
plt.plot(x.work_force, x.income, 'gx')
plt.show()

# %%
plt.figure(figsize = (12,5))
plt.plot(x.work_force, x.income, 'g^')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dotted", marker = 'o')
plt.title("work_force vs income")
plt.subplot(1,2,2)
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = ":" , marker = 'o')
plt.title("physicians vs income")
 #It will only work with plt.legend
plt.show()
#1 row two coloumn

# %%
plt.subplot(2,1,1) #row, coloumn, index
plt.plot(x.work_force, x.income, color = "r", label = "work_force", linestyle = "dotted", marker = 'o')
plt.title("work_force vs income")
plt.subplot(2,1,2)
plt.plot(x.physicians, x.income, color = "g", label = "physicians", linestyle = ":" , marker = 'o')
plt.title("physicians vs income")
 #It will only work with plt.legend
plt.show()

# %%
plt.scatter(x.hospital_beds, x.physicians)
plt.show()

# %%
plt.hist(x.region)
# Out:
# (array([21.,  0.,  0., 25.,  0.,  0., 36.,  0.,  0., 17.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x.income)
# Out:
# (array([80.,  9.,  4.,  2.,  2.,  0.,  0.,  1.,  0.,  1.]),
#  array([  769. ,  7902.1, 15035.2, 22168.3, 29301.4, 36434.5, 43567.6,
#         50700.7, 57833.8, 64966.9, 72100. ]),
#  <a list of 10 Patch objects>)
